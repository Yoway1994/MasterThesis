# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r'D:\Desktop\樣本資料\pump'
os.chdir(path)
os.listdir()
df = pd.read_csv('1Values.csv')

# %%
plt.plot(df['X0'], df['Y0'], 'k')
plt.plot(df['X1'], df['Y1'], 'b--')
ax = plt.gca()
sp = ['right', 'left', 'top', 'bottom']
for i in sp:
    ax.spines[i].set_color('black')
    ax.spines[i].set_linewidth(2)
ax.tick_params(axis = "y", direction = "in")
ax.tick_params(axis = "x", direction = "in")
plt.xlabel('Distance (μm)', fontsize = 16)
plt.ylabel('Gray value', fontsize = 16)
plt.legend(loc = 'best', labels = ['measurement', 'simulation'])
plt.show()
