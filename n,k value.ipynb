# %%
T_W = [417.08, 434.35, 453.4, 476.4, 502, 532.85, 567.83, 610.19, 659.48, 721.25, 794.42, 886.99, 1006.36, 1169.87, 1396.24, 1732.51]
T_n = [2.36166, 2.33, 2.29704, 2.27164, 2.24408, 2.2232, 2.19992, 2.18217, 2.16189, 2.14945, 2.13077, 2.11472, 2.09939, 2.09186, 2.08053, 2.06528]
T_k = [0.00174, 0.0016, 0.00144, 0.00131, 0.0013, 0.00134, 0.00132, 0.00128, 0.00127, 0.00128, 0.00126, 0.00128, 0.00141, 0.00164, 0.00189, 0.00219]
S_W = [410.28, 437.79, 471.76, 678.54, 763.94, 862.38, 1008.13, 1217.15, 1475.48]
S_n = [1.44191, 1.43462, 1.42892, 1.42377, 1.42435, 1.42366, 1.42194, 1.41782, 1.4128]
S_k = [0.0002, 0.00022, 0.00024, 0.00029, 0.0003, 0.00033, 0.00038, 0.0005, 0.00068]

# %%
import matplotlib.pyplot as plt
sp = ['right', 'left', 'top', 'bottom']

fig1 = plt.figure('TiO2')
ax1 = fig1.add_subplot(111)
ax1.tick_params(axis = 'y', direction = 'in')
ax1.tick_params(axis = 'x', direction = 'in')
ax1.set_ylabel('refractive index')
ax1.set_xlabel('wavelength (nm)')
ax1.plot(T_W, T_n, color = 'black', linestyle = '--', marker = 'o')

ax2 = plt.twinx()
for i in sp:
    ax2.spines[i].set_linewidth(3)
ax2.spines['right'].set_color('red')
ax2.tick_params(axis = 'y', colors = 'red', direction = 'in')
ax2.set_ylabel('extinction coefficient')
ax2.plot(T_W, T_k, linestyle = '--', color = 'red', marker = 's')
fig1.legend(loc = 1, labels = ['refractive index', 'extinction coefficient'], bbox_to_anchor=(0.7,1), bbox_transform = ax1.transAxes)

fig2 = plt.figure('SiO2')
ax3 = fig2.add_subplot(111)
ax3.tick_params(axis = 'y', direction = 'in')
ax3.tick_params(axis = 'x', direction = 'in')
ax3.set_ylabel('refractive index')
ax3.set_xlabel('wavelength (nm)')
ax3.plot(S_W, S_n, color = 'black', linestyle = '--', marker = 'o')

ax4 = plt.twinx()
for i in sp:
    ax4.spines[i].set_linewidth(3)
ax4.spines['right'].set_color('red')
ax4.tick_params(axis = 'y', colors = 'red', direction = 'in')
ax4.set_ylabel('extinction coefficient')
ax4.plot(S_W, S_k, linestyle = '--', color = 'red', marker = 's')
fig2.legend(loc = 1, labels = ['refractive index', 'extinction coefficient'], bbox_to_anchor=(0.7,1), bbox_transform = ax1.transAxes)

plt.show()
