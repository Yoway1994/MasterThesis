# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
path = r'D:\desktop\140523-2'
os.chdir(path)
file1 = os.listdir()[3]

path = r'D:\desktop\high'
os.chdir(path)
file2 = os.listdir()[1]

data1 = pd.read_csv(file1)
data2 = pd.read_csv(file2)

# %%
plt.plot(data1['pump'], data1['Gain'])
plt.plot(data2['pump'], data2['Gain'])
plt.show()
