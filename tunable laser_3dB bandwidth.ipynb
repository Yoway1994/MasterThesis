# %%
b_w = [1409, 1420, 1422, 1436, 1442, 1446, 1466, 1475]
b_p = [10, 60, 120, 230, 310, 300, 170, 50]
f_w = [1409, 1422, 1438, 1443, 1447, 1462.6, 1467.7]
f_p = [8.4, 15, 20, 31, 23.7, 17, 13.7]
LD_w = [1372, 1389, 1405, 1413, 1445.7, 1447.9, 1451.4, 1453.5, 1474.6, 1479.9, 1485.5]
LD_p = [7.6, 10.8, 16.1, 24, 30, 36, 37, 41, 28, 27, 20]

import numpy as np
lambda_c = 1447
x = np.linspace(1400, 1500, 101)
K_e = 0.016
g = np.exp(-((x-lambda_c)/(K_e*x))**2)

import matplotlib.pyplot as plt
plt.plot(b_w, b_p/np.max(b_p), 'ko')
#plt.plot(f_w, f_p/np.max(f_p), 'ko')
#plt.plot(LD_w, LD_p/np.max(LD_p), 'ko')
plt.plot(x, g/np.max(g))

plt.xlabel('')
plt.ylabel('')
plt.show()
