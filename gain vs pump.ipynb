# %%
import matplotlib.pyplot as plt
import pandas as pd

data1 = pd.read_csv(r'D:\desktop\high\gain.csv')
data2 = pd.read_csv(r'D:\desktop\140523-2\gain.csv')

ax = plt.gca()
sp = ['right', 'left', 'top', 'bottom']
for i in sp:
    ax.spines[i].set_color('black')
    ax.spines[i].set_linewidth(2)
ax.tick_params(axis = "y", direction = "in")
ax.tick_params(axis = "x", direction = "in")

plt.plot(data1['pump'], data1['Gain'], 'r-', label = 'high concentration')
plt.plot(data2['pump'], data2['Gain'], 'b-', label = 'normal')
plt.ylabel('Gain (dB)', fontsize = 14)
plt.xlabel('Input pump power (W)', fontsize = 14)
plt.legend(loc = 'best')

plt.show()
