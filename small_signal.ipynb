# %%
X1 = [-4.213128098, -3.352407217, -2.505109357, -1.864962873, -1.480424909, -1.23147945, -1.042198199, -0.949949477, -0.879964377, -0.826395728, -0.795065352, -0.779187482, -0.746134954, -0.739360024, -0.72536806, -0.725550605, -0.725113373]
Y1 = [24.63, 57.9, 110.2, 172.4, 235.6, 304.5, 362.5, 435.4, 506.2, 568, 636.2, 709, 751.9, 810, 846, 890, 918]
X2 = [-7.22520951, -6.945111066, -6.577253209, -6.02131751, -5.225615535, -4.434544669, -3.795223738, -3.269428104, -2.945017181, -2.704097627, -2.590267165, -2.523822066, -2.562868191, -2.541989165, -2.519649598, -2.525728644, -2.51724203]
Y2 = [24.9818, 59.9422, 119.833, 203.505, 303.36, 424.9, 552.3, 683, 819.5, 942.4, 1073, 1205, 1329, 1428, 1508, 1587, 1618]

# %%
import pandas as pd
import os
import numpy as np
os.chdir(r'D:\desktop')
f = pd.DataFrame(X1)
f.to_csv('test.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np
x2 = np.linspace(-10,0)
y2 = 0.14*x2 + 1.02
plt.plot(x2, y2, 'k--')
plt.plot(X2, np.array(Y2)*10**-3, 'ro', label = 'high concentration')
plt.ylim(-0.05, 1.75)
plt.xlim(-7.5, 0)

x1 = np.linspace(-10, 0)
y1 = 0.062*x1 + 0.28
plt.plot(x1, y1, 'k--')
plt.plot(X1, np.array(Y1)*10**-3, 'bs', label = 'normal')

ax = plt.gca()
sp = ['right', 'left', 'top', 'bottom']
for i in sp:
    ax.spines[i].set_color('black')
    ax.spines[i].set_linewidth(2)
ax.tick_params(axis = "y", direction = "in")
ax.tick_params(axis = "x", direction = "in")

plt.xlabel('X', fontsize = 14)
plt.ylabel('Y (W)', fontsize = 14)
plt.legend(loc = 'upper left')

plt.show()
